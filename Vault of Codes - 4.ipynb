# %% [markdown]
# # Internship - Week 4
# ## Codes after Debugging

# %% [markdown]
# ###  Objective: Project
# #### Expense Tracker

# %%
import matplotlib.pyplot as plt

class ExpenseTracker:
    def __init__(self):
        self.expenses = []

    def add_expense(self, category, amount):
        self.expenses.append((category, amount))

    def get_total_expense(self):
        return sum(amount for category, amount in self.expenses)

    def get_expenses_by_category(self, category):
        return [(cat, amount) for cat, amount in self.expenses if cat == category]

    def display_expenses(self):
        for category, amount in self.expenses:
            print(f"Category: {category}, Amount: {amount}")

    def plot_expenses_by_category(self):
        categories = set(category for category, _ in self.expenses)
        category_expenses = {cat: 0 for cat in categories}

        for category, amount in self.expenses:
            category_expenses[category] += amount

        plt.figure(figsize=(10, 6))
        plt.bar(category_expenses.keys(), category_expenses.values())
        plt.xlabel('Categories')
        plt.ylabel('Amount')
        plt.title('Expense Analysis by Category')
        plt.show()

def main():
    tracker = ExpenseTracker()

    while True:
        print("\nExpense Tracker Menu:")
        print("1. Add Expense")
        print("2. View Total Expenses")
        print("3. View Expenses by Category")
        print("4. View All Expenses")
        print("5. Plot Expenses by Category")
        print("6. Quit")

        choice = input("Enter your choice (1-6): ")

        if choice == "1":
            category = input("Enter expense category: ")
            amount = float(input("Enter expense amount: "))
            tracker.add_expense(category, amount)
            print("Expense added successfully.")

        elif choice == "2":
            total_expense = tracker.get_total_expense()
            print(f"Total Expenses: {total_expense}")

        elif choice == "3":
            category = input("Enter category to view expenses: ")
            expenses = tracker.get_expenses_by_category(category)
            if expenses:
                print(f"Expenses for {category}:")
                for cat, amount in expenses:
                    print(f"Category: {cat}, Amount: {amount}")
            else:
                print(f"No expenses found for {category}.")

        elif choice == "4":
            print("All Expenses:")
            tracker.display_expenses()

        elif choice == "5":
            tracker.plot_expenses_by_category()

        elif choice == "6":
            print("Exiting Expense Tracker. Goodbye!")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Textbooks
# Enter expense amount: 1000
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Transporation
# Enter expense amount: 300
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Eating Out
# Enter expense amount: 2000
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Stationary
# Enter expense amount: 200
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): Internet Bill
# Invalid choice. Please try again.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Internet Bill
# Enter expense amount: 300
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Entertainment
# Enter expense amount: 500
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): College Fee
# Invalid choice. Please try again.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 10000
# Invalid choice. Please try again.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: College Fee
# Enter expense amount: 10000
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 1
# Enter expense category: Hostel Fee
# Enter expense amount: 8000
# Expense added successfully.
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 2
# Total Expenses: 22300.0
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 3
# Enter category to view expenses: College Fee
# Expenses for College Fee:
# Category: College Fee, Amount: 10000.0
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 4
# All Expenses:
# Category: Textbooks, Amount: 1000.0
# Category: Transporation, Amount: 300.0
# Category: Eating Out, Amount: 2000.0
# Category: Stationary, Amount: 200.0
# Category: Internet Bill, Amount: 300.0
# Category: Entertainment, Amount: 500.0
# Category: College Fee, Amount: 10000.0
# Category: Hostel Fee, Amount: 8000.0
#
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 5
# Expense Tracker Menu:
# 1. Add Expense
# 2. View Total Expenses
# 3. View Expenses by Category
# 4. View All Expenses
# 5. Plot Expenses by Category
# 6. Quit
# Enter your choice (1-6): 6
# Exiting Expense Tracker. Goodbye!
